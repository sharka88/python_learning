# %%
from bokeh.plotting import show, figure
from bokeh.io import output_notebook

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e073a286-914a-42e9-8c13-511c2f3b18c2">Loading BokehJS ...</span>
#     </div>

# %%
plot=figure(width=500,height=500)
plot.line(x=[1,2,3,4,5],y=[5,2,7,3,6])
show(plot)
# Out:
#   <div class="bk-root" id="ee571336-c85b-4336-9d32-b8ef5f7fc50a"></div>
